# %%
import cv2

# %%
import numpy as np

# %%
img1 = cv2.imread("/home/crazy/Downloads/panda3.jpg")

# %%
img1 = cv2.resize(img1,(100,100))

# %%
img2 = cv2.imread("/home/crazy/Downloads/panda2.jpg")

# %%
img2 = cv2.resize(img2,(100,100))

# %%
img = np.array([img1,img2])

# %%
np.savez("plotimages",img)

# %%
arr = np.load("plotimages.npz")['arr_0']

# %%
import matplotlib.pyplot as plt

# %%
plt.imshow(arr[0])
