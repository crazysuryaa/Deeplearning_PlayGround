# %%
import tkinter as tk
root = tk.Tk()

def motion(event):
    x, y = event.x, event.y
    print('{}, {}'.format(x, y))

root.bind('<Motion>', motion)
root.mainloop()
# Out:
# 344, 321
# 344, 321
# 350, 318
# 368, 303
# 394, 279
# 424, 255
# 456, 235
# 492, 215
# 528, 193
# 564, 175
# 594, 157
# 618, 143
# 636, 133
# 642, 128
# 649, 124
# 651, 122
# 652, 121
# 648, 121
# 639, 121
# 619, 129
# 597, 133
# 569, 141
# 537, 151
# 507, 157
# 473, 161
# 439, 167
# 409, 171
# 375, 177
# 349, 179
# 325, 183
# 301, 187
# 277, 189
# 257, 189
# 231, 192
# 207, 192
# 185, 192
# 168, 192
# 154, 192
# 150, 192
# 148, 192
# 147, 192
# 147, 191
# 149, 189
# 151, 188
# 154, 187
# 160, 185
# 166, 184
# 174, 181
# 183, 178
# 191, 177
# 199, 175
# 208, 171
# 215, 171
# 219, 170
# 223, 170
# 225, 170
# 229, 170
# 231, 169
# 234, 169
# 236, 169
# 240, 169
# 246, 169
# 252, 169
# 258, 169
# 266, 169
# 279, 169
# 286, 169
# 294, 169
# 299, 171
# 305, 172
# 307, 174
# 313, 176
# 316, 178
# 319, 180
# 324, 182
# 327, 186
# 329, 188
# 332, 191
# 335, 193
# 336, 195
# 339, 200
# 339, 201
# 340, 205
# 342, 209
# 343, 211
# 343, 217
# 343, 222
# 344, 225
# 344, 228
# 344, 231
# ...

# %%
# Out:
# 1080

# %%
import tkinter as tk
from tkinter import *


from PIL import Image, ImageTk


# canvas = tk.Canvas(root,height = 1080,width = 1920)
# canvas.pack()



main = tk.Tk()
# sh = main.winfo_screenheight()
# sw = main.winfo_screenheight()
main.geometry("1880x1080")
main.resizable(width = "True",height = "True")





frame1 = tk.Frame(main, width=320, height=200, background="red")

image = Image.open("bg3.png")
bg = ImageTk.PhotoImage(image)

b1 = Button(frame1,text = "B1",bg = "red",width = 100,height = 100,image = bg)
b2 = Button(frame1,text = "B2",bg = "white",width = 100,height = 100,image = bg)
b3 = Button(frame1,text = "B3" , bg = "green",width = 100,height = 100,image = bg)
b4 = Button(frame1,text = "B4" , bg = "yellow",width = 100,height = 100,image = bg)
b5 = Button(frame1,text = "B5" , bg = "green",width = 100,height = 100,image = bg)
b6 = Button(frame1,text = "B6" , bg = "yellow",width = 100,height = 100,image = bg)
            
            
b1.grid(row = 0 , column = 0)
b2.grid(row = 0 , column = 1)
b3.grid(row = 0 , column = 2)
b4.grid(row = 1 , column = 0)
b5.grid(row = 1 , column = 1)
b6.grid(row = 1 , column = 2)


frame2 = tk.Frame(main, width=320, height = 200, background="green")

# b1 = Button(f1,text = "B1",bg = "red",width = 100,height = 100,image = bg)
# b2 = Button(f1,text = "B2",bg = "white",width = 6)
# b3 = Button(f2,text = "B3" , bg = "green",width = 6)
# b4 = Button(f2,text = "B4" , bg = "yellow",width = 6)

# b1.grid(row = 0 , column = 0)
# b2.grid(row = 0 , column = 1)
# b3.grid(row = 0 , column = 0)
# b4.grid(row = 0 , column = 1)

frame3 = tk.Frame(main, width=320, height=200, background="blue")

# b1 = Button(f1,text = "B1",bg = "red",width = 100,height = 100,image = bg)
# b2 = Button(f1,text = "B2",bg = "white",width = 6)
# b3 = Button(f2,text = "B3" , bg = "green",width = 6)
# b4 = Button(f2,text = "B4" , bg = "yellow",width = 6)

# b1.grid(row = 0 , column = 0)
# b2.grid(row = 0 , column = 1)
# b3.grid(row = 0 , column = 0)
# b4.grid(row = 0 , column = 1)

frame4 = tk.Frame(main, width=320, height = 200, background="white")


# b1 = Button(f1,text = "B1",bg = "red",width = 100,height = 100,image = bg)
# b2 = Button(f1,text = "B2",bg = "white",width = 6)
# b3 = Button(f2,text = "B3" , bg = "green",width = 6)
# b4 = Button(f2,text = "B4" , bg = "yellow",width = 6)

# b1.grid(row = 0 , column = 0)
# b2.grid(row = 0 , column = 1)
# b3.grid(row = 0 , column = 0)
# b4.grid(row = 0 , column = 1)

frame5 = tk.Frame(main, width=320, height=200, background="black")

# b1 = Button(f1,text = "B1",bg = "red",width = 100,height = 100,image = bg)
# b2 = Button(f1,text = "B2",bg = "white",width = 6)
# b3 = Button(f2,text = "B3" , bg = "green",width = 6)
# b4 = Button(f2,text = "B4" , bg = "yellow",width = 6)

# b1.grid(row = 0 , column = 0)
# b2.grid(row = 0 , column = 1)
# b3.grid(row = 0 , column = 0)
# b4.grid(row = 0 , column = 1)


frame6 = tk.Frame(main, width=320, height=200, background="pink")
# b1 = Button(f1,text = "B1",bg = "red",width = 100,height = 100,image = bg)
# b2 = Button(f1,text = "B2",bg = "white",width = 6)
# b3 = Button(f2,text = "B3" , bg = "green",width = 6)
# b4 = Button(f2,text = "B4" , bg = "yellow",width = 6)

# b1.grid(row = 0 , column = 0)
# b2.grid(row = 0 , column = 1)
# b3.grid(row = 0 , column = 0)
# b4.grid(row = 0 , column = 1)


frame7 = tk.Frame(main, width=1920, height = 880, background="yellow")
canvas = tk.Canvas(frame7,width=1920, height = 880,bg = "black")

canvas.pack()



frame1.grid(row = 1 , column = 0)
frame2.grid(row = 1 , column = 1)
frame3.grid(row = 1 , column = 2)
frame4.grid(row = 1 , column = 3)
frame5.grid(row = 1 , column = 4)
frame6.grid(row = 1 , column = 5)

frame7.grid(row = 0,columnspan = 6)

canvas.create_image(0, 0, image = bg, anchor = NW)
main.mainloop()

# %%
frame1 = tk.Frame(root, width=100, height=100, background="bisque")
frame2 = tk.Frame(root, width=50, height = 50, background="#b22222")

frame1.pack(fill=None, expand=False)
frame2.place(relx=.5, rely=.5, anchor="c")

root.mainloop()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-c5251d22b394> in <module>
# ----> 1 frame1 = tk.Frame(root, width=100, height=100, background="bisque")
#       2 frame2 = tk.Frame(root, width=50, height = 50, background="#b22222")
#       3
#       4 frame1.pack(fill=None, expand=False)
#       5 frame2.place(relx=.5, rely=.5, anchor="c")
#
# NameError: name 'tk' is not defined

# %%
import tkinter as tk
from tkinter import *

from PIL import Image, ImageTk



root = tk.Tk()


canvas = tk.Canvas(root,height = 1080,width = 1920)
canvas.pack()
image = Image.open("bg3.png")
bg = ImageTk.PhotoImage(image)
# canvas.create_image(0,0,image = bg)




bglabel = tk.Label(root,image = bg)
bglabel.place(relwidth =1 ,relheight =1,relx = 0,rely = 0)




    

root.mainloop()

# %%
import tkinter as tk
from tkinter import *

from PIL import Image, ImageTk


win = Tk()
win.geometry("500x500")

f1 = Frame(win ,relief = "raised",borderwidth = 8,width=300, height=300, background="red")
f2 = Frame(win,relief = "sunken",borderwidth = 8,width=300, height=300, background="black")

# f1.geometry("500x500")
# f2.geometry("500x500")


image = Image.open("button.png")
bg = ImageTk.PhotoImage(image)

b1 = Button(f1,text = "B1",bg = "red",width = 100,height = 100,image = bg)
b2 = Button(f1,text = "B2",bg = "white",width = 6)
b3 = Button(f2,text = "B3" , bg = "green",width = 6)
b4 = Button(f2,text = "B4" , bg = "yellow",width = 6)

b1.grid(row = 0 , column = 0)
b2.grid(row = 0 , column = 1)
b3.grid(row = 0 , column = 0)
b4.grid(row = 0 , column = 1)

f1.grid(row = 0 , column =0)
f2.grid(row = 1 , column =1)

win.mainloop()

# %%
def drag_start(event):
    """Begining drag of an object"""
    # record the item and its location
    _drag_data["item"] = canvas.find_closest(event.x, event.y)[0]
    _drag_data["x"] = event.x
    _drag_data["y"] = event.y
    print("initial",event.x,event.y)

def drag_stop(event):
    """End drag of an object"""
    # reset the drag information
    _drag_data["item"] = None
    _drag_data["x"] = 0
    _drag_data["y"] = 0

def drag(event):
    """Handle dragging of an object"""
    # compute how much the mouse has moved
    delta_x = event.x - _drag_data["x"]
    delta_y = event.y - _drag_data["y"]
    # move the object the appropriate amount
    canvas.move(_drag_data["item"], delta_x, delta_y)
    # record the new position
    _drag_data["x"] = event.x
    _drag_data["y"] = event.y
    print("final",event.x,event.y)

# %%
_drag_data = {"x": 0, "y": 0, "item": None}
global currentx,currenty
currenty  = 400
currentx = 10

# %%
def create_token(x, y, color,label):
    print("button ",label," is pressed")
    canvas.create_oval(
    x - 25,
    y - 25,
    x + 25,
    y + 25,
    outline=color,
    fill=color,
    tags=("token",))
    currentx = currentx+20

# %%
import tkinter as tk
from tkinter import *


from PIL import Image, ImageTk


# canvas = tk.Canvas(root,height = 1080,width = 1920)
# canvas.pack()



main = tk.Tk()
# sh = main.winfo_screenheight()
# sw = main.winfo_screenheight()
main.geometry("1880x1080")
main.resizable(width = "True",height = "True")




frame1 = tk.Frame(main, width=1920, height=20, background="red")

image = Image.open("bg3.png")
bg = ImageTk.PhotoImage(image)

b1 = Button(frame1,text = "B1",bg = "red",height = 10,image = bg)
b2 = Button(frame1,text = "B2",bg = "white",height = 10,image = bg)
b3 = Button(frame1,text = "B3" , bg = "green",height = 10,image = bg)
b4 = Button(frame1,text = "B4" , bg = "yellow",height = 10,image = bg)
b5 = Button(frame1,text = "B5" , bg = "green",height = 10,image = bg)
b6 = Button(frame1,text = "B6" , bg = "yellow",height = 10,image = bg)

b1.bind("<ButtonPress-1>",lambda event, a = currentx , b = currenty, c="black",d =1: create_token(a, b, c,d))
b2.bind("<ButtonPress-1>",lambda event, a = currentx , b = currenty, c="red",d =1: create_token(a, b, c,d))
b3.bind("<ButtonPress-1>",lambda event, a = currentx , b = currenty, c="green",d =1: create_token(a, b, c,d))
b4.bind("<ButtonPress-1>",lambda event,a = currentx , b = currenty, c="white",d =1: create_token(a, b, c,d))
b5.bind("<ButtonPress-1>",lambda event, a = currentx , b = currenty, c="yellow",d =1: create_token(a, b, c,d))
b6.bind("<ButtonPress-1>",lambda event, a = currentx , b = currenty, c="blue",d =1: create_token(a, b, c,d))
                                        
# b1.grid(row = 0 , column = 0)
# b2.grid(row = 0 , column = 1)
# b3.grid(row = 0 , column = 2)
# b4.grid(row = 1 , column = 0)
# b5.grid(row = 1 , column = 1)
# b6.grid(row = 1 , column = 2)

b1.place(relwidth = 0.15,relx = 0)
b2.place(relwidth = 0.15,relx = 0.17)
b3.place(relwidth = 0.15,relx = 0.34)
b4.place(relwidth = 0.15,relx = 0.51)
b5.place(relwidth = 0.15,relx = 0.68)
b6.place(relwidth = 0.15,relx = 0.85)

frame7 = tk.Frame(main, width=1920, height = 880, background="yellow")
canvas = tk.Canvas(frame7,width=1920, height = 880,bg = "black")


canvas.tag_bind("token", "<ButtonPress-1>", drag_start)
canvas.tag_bind("token", "<ButtonRelease-1>", drag_stop)
canvas.tag_bind("token", "<B1-Motion>", drag)


canvas.pack()



frame1.grid(row = 1 , columnspan = 3)

frame7.grid(row = 0, columnspan = 3)

canvas.create_image(0, 0, image = bg, anchor = NW)
main.mainloop()
# Out:
# button  1  is pressed
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "/home/crazy/anaconda3/lib/python3.7/tkinter/__init__.py", line 1705, in __call__
#     return self.func(*args)
#   File "<ipython-input-18-2e5134701a38>", line 35, in <lambda>
#     b2.bind("<ButtonPress-1>",lambda event, a = currentx , b = currenty, c="red",d =1: create_token(a, b, c,d))
#   File "<ipython-input-17-c0c1e88ebc40>", line 11, in create_token
#     currentx = currentx+20
# UnboundLocalError: local variable 'currentx' referenced before assignment
# button  1  is pressed
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "/home/crazy/anaconda3/lib/python3.7/tkinter/__init__.py", line 1705, in __call__
#     return self.func(*args)
#   File "<ipython-input-18-2e5134701a38>", line 36, in <lambda>
#     b3.bind("<ButtonPress-1>",lambda event, a = currentx , b = currenty, c="green",d =1: create_token(a, b, c,d))
# ...

# %%
import tkinter as tk
from tkinter import *


from PIL import Image, ImageTk

temp = 0
class Ex():
    def __init__(self,initx,inity):
        self.main = tk.Tk()
        # sh = self.main.winfo_screenheight()
        # sw = self.main.winfo_screenheight()
        self.main.geometry("1880x1080")
        self.main.resizable(width = "True",height = "True")
        self._drag_data = {"x": 0, "y": 0, "item": None}
        self.currenty  = inity
        self.currentx = initx
        self.frame1 = tk.Frame(self.main, width=1920, height=200, background="red")

        image = Image.open("bg3.png")
        bg = ImageTk.PhotoImage(image)

        self.b1 = Button(self.frame1,text = "self.b1",bg = "red",height = 100,image = bg)
        self.b2 = Button(self.frame1,text = "self.b2",bg = "white",height = 100,image = bg)
        self.b3 = Button(self.frame1,text = "self.b3" , bg = "green",height = 100,image = bg)
        self.b4 = Button(self.frame1,text = "self.b4" , bg = "yellow",height = 100,image = bg)
        self.b5 = Button(self.frame1,text = "self.b5" , bg = "green",height = 100,image = bg)
        self.b6 = Button(self.frame1,text = "self.b6" , bg = "yellow",height = 100,image = bg)

        self.b1.bind("<ButtonPress-1>",lambda event, a = self.currentx , b =  self.currenty, c="black",d =1: self.create_token(a, b, c,d))
        self.b2.bind("<ButtonPress-1>",lambda event, a = self.currentx , b =  self.currenty, c="red",d =1: self.create_token(a, b, c,d))
        self.b3.bind("<ButtonPress-1>",lambda event, a = self.currentx , b =  self.currenty, c="green",d =1: self.create_token(a, b, c,d))
        self.b4.bind("<ButtonPress-1>",lambda event,a = self.currentx , b =  self.currenty, c="white",d =1: self.create_token(a, b, c,d))
        self.b5.bind("<ButtonPress-1>",lambda event, a = self.currentx , b =  self.currenty, c="yellow",d =1: self.create_token(a, b, c,d))
        self.b6.bind("<ButtonPress-1>",lambda event, a = self.currentx , b =  self.currenty, c="blue",d =1: self.create_token(a, b, c,d))

        # self.b1.grid(row = 0 , column = 0)
        # self.b2.grid(row = 0 , column = 1)
        # self.b3.grid(row = 0 , column = 2)
        # self.b4.grid(row = 1 , column = 0)
        # self.b5.grid(row = 1 , column = 1)
        # self.b6.grid(row = 1 , column = 2)

        self.b1.place(relwidth = 0.15,relx = 0)
        self.b2.place(relwidth = 0.15,relx = 0.17)
        self.b3.place(relwidth = 0.15,relx = 0.34)
        self.b4.place(relwidth = 0.15,relx = 0.51)
        self.b5.place(relwidth = 0.15,relx = 0.68)
        self.b6.place(relwidth = 0.15,relx = 0.85)

        self.frame7 = tk.Frame(self.main, width=1920, height = 880, background="yellow")
        self.canvas = tk.Canvas(self.frame7,width=1920, height = 880,bg = "black")


        self.canvas.tag_bind("token", "<ButtonPress-1>", self.drag_start)
        self.canvas.tag_bind("token", "<ButtonRelease-1>", self.drag_stop)
        self.canvas.tag_bind("token", "<B1-Motion>", self.drag)


        self.canvas.pack()



        self.frame1.grid(row = 1 , columnspan = 3)

        self.frame7.grid(row = 0, columnspan = 3)

        self.canvas.create_image(0, 0, image = bg, anchor = NW)

    def drag_start(self, event):
        """Begining drag of an object"""
        # record the item and its location
        self._drag_data["item"] = self.canvas.find_closest(event.x, event.y)[0]
        self._drag_data["x"] = event.x
        self._drag_data["y"] = event.y
#         print("initial",event.x,event.y)

    def drag_stop(self, event):
        """End drag of an object"""
        # reset the drag information
        self._drag_data["item"] = None
        self._drag_data["x"] = 0
        self._drag_data["y"] = 0

    def drag(self, event):
        """Handle dragging of an object"""
        # compute how much the mouse has moved
        delta_x = event.x - self._drag_data["x"]
        delta_y = event.y - self._drag_data["y"]
        # move the object the appropriate amount
        self.canvas.move(self._drag_data["item"], delta_x, delta_y)
        # record the new position
        self._drag_data["x"] = event.x
        self._drag_data["y"] = event.y
#         print("final",event.x,event.y)
        
        
    def create_token(self,x, y, color,label):
        print("button ",label," is pressed")
        print(x,y)
        self.canvas.create_oval(
        x - 25,
        y - 25,
        x + 25,
        y + 25,
        outline=color,
        fill=color,
        tags=("token",))
#         self.currentx = self.currentx+20
        self.currentx +=20
        
        
win = Ex()
win.main
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-3-662869b21128> in <module>
#     113
#     114
# --> 115 win = Ex()
#     116 win.mainlo
#
# <ipython-input-3-662869b21128> in __init__(self, main)
#      13         # sh = self.main.winfo_screenheight()
#      14         # sw = self.main.winfo_screenheight()
# ---> 15         self.main.geometry("1880x1080")
#      16         self.main.resizable(width = "True",height = "True")
#      17         self._drag_data = {"x": 0, "y": 0, "item": None}
#
# AttributeError: 'NoneType' object has no attribute 'geometry'

# %%
app = Ex(20,400)

# %%
def f1(i):
    print("conv",i)
    pass
def f2(i):
    print("dense",i)
def f3(i):
    print("act",i)

# %%
[2,4,5]
# Out:
# [2, 4, 5]

# %%
dic = list( () for i in range(100) )

# %%
dic
# Out:
# [(),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  ()]

# %%
dic[2] = (10,20,f1)

# %%
dic[4] = (40,60,f2)
dic[5] = (70,80,f3)

# %%
def onclick(i):
    dic[i][2](i)

# %%
onclick(5)
# Out:
# act 5

# %%
dic = {"x" : 0 , "y" : 0 , "item" : None}

# %%
class ConvDialog:

    def __init__(self, parent):
        conv =  tk.Toplevel(parent)
        conv.geometry("200x200")
        conv.resizable(width = "False",height = "False")
        conv.title("conv")

        v1 = StringVar(conv, value='64')
        v2 = StringVar(conv, value='(3,3)')
        v3 = StringVar(conv, value='(2,2)')
        v4 = StringVar(conv, value='same')
        v5 = StringVar(conv, value='relu')
        v6 = StringVar(conv, value='1')

        e1 = Entry(conv, textvariable=v1)
        e2 = Entry(conv, textvariable=v2)
        e3 = Entry(conv, textvariable=v3)
        e4 = Entry(conv, textvariable=v4)
        e5 = Entry(conv, textvariable=v5)
        e6 = Entry(conv, textvariable=v6)

        l1 = Label(conv,text = "filters")
        l2 = Label(conv,text = "kernal size")
        l3 = Label(conv,text = "strides")
        l4 = Label(conv,text = "padding")
        l5 = Label(conv,text = "activation")
        l6 = Label(conv,text = "dilation")


        l1.grid(row = 0 , column = 0)
        l2.grid(row = 1 , column = 0)
        l3.grid(row = 2 , column = 0)
        l4.grid(row = 3 , column = 0)
        l5.grid(row = 4 , column = 0)
        l6.grid(row = 5 , column = 0)

        e1.focus_set()
        e1.grid(row = 0 , column = 1)
        e2.grid(row = 1 , column = 1)
        e3.grid(row = 2 , column = 1)
        e4.grid(row = 3 , column = 1)
        e5.grid(row = 4 , column = 1)
        e6.grid(row = 5 , column = 1)

        submit = Button(conv,text = "Submit",pady = 10)
        submit.grid(row = 6 ,columnspan = 2)
        submit.bind("<ButtonPress-1>",lambda event, a = e1 , b = e2 , c = e3,d = e4 ,e = e5 ,f = e6 ,g = 1: self.printtext(a, b, c,d,e,f,g))
        self.conv = conv
        
        
    def printtext(self,e1,e2,e3,e4,e5,e6,g):
        a = e1.get() 
        b = e2.get()
        c = e3.get()
        d = e4.get()
        e = e5.get() 
        f = e6.get()
        print(a,b,c,d,e,f,g)
        self.conv.destroy()

# %%
import tkinter as tk
from tkinter import *


def printtext(e1,e2,e3,e4,e5,e6,g):
    a = e1.get() 
    b = e2.get()
    c = e3.get()
    d = e4.get()
    e = e5.get() 
    f = e6.get()
    print(a,b,c,d,e,f,g)
    top.destroy()


root = tk.Tk()
mainLabel = tk.Label(root, text='Example for pop up input box')
mainLabel.pack()

mainButton = tk.Button(root, text='Click me', command=onClick)
mainButton.pack()
    
    
conv = Toplevel(root)
conv.geometry("200x200")
conv.resizable(width = "False",height = "False")
conv.title("conv")

v1 = StringVar(conv, value='64')
v2 = StringVar(conv, value='(3,3)')
v3 = StringVar(conv, value='(2,2)')
v4 = StringVar(conv, value='same')
v5 = StringVar(conv, value='relu')
v6 = StringVar(conv, value='1')

e1 = Entry(conv, textvariable=v1)
e2 = Entry(conv, textvariable=v2)
e3 = Entry(conv, textvariable=v3)
e4 = Entry(conv, textvariable=v4)
e5 = Entry(conv, textvariable=v5)
e6 = Entry(conv, textvariable=v6)


# e1 = Entry(conv)
# e2 = Entry(conv)
# e3 = Entry(conv)
# e4 = Entry(conv)
# e5 = Entry(conv)
# e6 = Entry(conv)



l1 = Label(conv,text = "filters")
l2 = Label(conv,text = "kernal size")
l3 = Label(conv,text = "strides")
l4 = Label(conv,text = "padding")
l5 = Label(conv,text = "activation")
l6 = Label(conv,text = "dilation")


l1.grid(row = 0 , column = 0)
l2.grid(row = 1 , column = 0)
l3.grid(row = 2 , column = 0)
l4.grid(row = 3 , column = 0)
l5.grid(row = 4 , column = 0)
l6.grid(row = 5 , column = 0)

e1.focus_set()
# e1.insert(END, )
# e2.insert(END, '(3,3)')
# e3.insert(END, '')
# e4.insert(END, 'same')
# e5.insert(END, 'relu')
# e6.insert(END, '1')



e1.grid(row = 0 , column = 1)
e2.grid(row = 1 , column = 1)
e3.grid(row = 2 , column = 1)
e4.grid(row = 3 , column = 1)
e5.grid(row = 4 , column = 1)
e6.grid(row = 5 , column = 1)




submit = Button(conv,text = "Submit",pady = 10)
submit.grid(row = 6 ,columnspan = 2)
# submit.bind("<ButtonPress-1>",lambda event, a = e1.get() , b = e2.get() , c = e3.get(),d = e4.get() ,e = e5.get() ,f = e6.get() ,g = 1: printtext(a, b, c,d,e,f,g))
submit.bind("<ButtonPress-1>",lambda event, a = e1 , b = e2 , c = e3,d = e4 ,e = e5 ,f = e6 ,g = 1: printtext(a, b, c,d,e,f,g))

root.mainloop()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-bb93e5630113> in <module>
#      18 mainLabel.pack()
#      19
# ---> 20 mainButton = tk.Button(root, text='Click me', command=onClick)
#      21 mainButton.pack()
#      22
#
# NameError: name 'onClick' is not defined

# %%
import tkinter as tk

class ConvDialog:

    def __init__(self, parent):
        conv =  tk.Toplevel(parent)
#         conv = Toplevel(self.top)
        conv.geometry("200x200")
        conv.resizable(width = "False",height = "False")
        conv.title("conv")

        v1 = StringVar(conv, value='64')
        v2 = StringVar(conv, value='(3,3)')
        v3 = StringVar(conv, value='(2,2)')
        v4 = StringVar(conv, value='same')
        v5 = StringVar(conv, value='relu')
        v6 = StringVar(conv, value='1')

        e1 = Entry(conv, textvariable=v1)
        e2 = Entry(conv, textvariable=v2)
        e3 = Entry(conv, textvariable=v3)
        e4 = Entry(conv, textvariable=v4)
        e5 = Entry(conv, textvariable=v5)
        e6 = Entry(conv, textvariable=v6)


        # e1 = Entry(conv)
        # e2 = Entry(conv)
        # e3 = Entry(conv)
        # e4 = Entry(conv)
        # e5 = Entry(conv)
        # e6 = Entry(conv)



        l1 = Label(conv,text = "filters")
        l2 = Label(conv,text = "kernal size")
        l3 = Label(conv,text = "strides")
        l4 = Label(conv,text = "padding")
        l5 = Label(conv,text = "activation")
        l6 = Label(conv,text = "dilation")


        l1.grid(row = 0 , column = 0)
        l2.grid(row = 1 , column = 0)
        l3.grid(row = 2 , column = 0)
        l4.grid(row = 3 , column = 0)
        l5.grid(row = 4 , column = 0)
        l6.grid(row = 5 , column = 0)

        e1.focus_set()
        # e1.insert(END, )
        # e2.insert(END, '(3,3)')
        # e3.insert(END, '')
        # e4.insert(END, 'same')
        # e5.insert(END, 'relu')
        # e6.insert(END, '1')



        e1.grid(row = 0 , column = 1)
        e2.grid(row = 1 , column = 1)
        e3.grid(row = 2 , column = 1)
        e4.grid(row = 3 , column = 1)
        e5.grid(row = 4 , column = 1)
        e6.grid(row = 5 , column = 1)

        submit = Button(conv,text = "Submit",pady = 10)
        submit.grid(row = 6 ,columnspan = 2)
        # submit.bind("<ButtonPress-1>",lambda event, a = e1.get() , b = e2.get() , c = e3.get(),d = e4.get() ,e = e5.get() ,f = e6.get() ,g = 1: printtext(a, b, c,d,e,f,g))
        submit.bind("<ButtonPress-1>",lambda event, a = e1 , b = e2 , c = e3,d = e4 ,e = e5 ,f = e6 ,g = 1: self.printtext(a, b, c,d,e,f,g))
        self.conv = conv
        
        
    def printtext(self,e1,e2,e3,e4,e5,e6,g):
        a = e1.get() 
        b = e2.get()
        c = e3.get()
        d = e4.get()
        e = e5.get() 
        f = e6.get()
        print(a,b,c,d,e,f,g)
        self.conv.destroy()

def onClick():
    inputDialog = ConvDialog(root)

root = tk.Tk()
mainLabel = tk.Label(root, text='Example for pop up input box')
mainLabel.pack()

mainButton = tk.Button(root, text='Click me', command=onClick)
mainButton.pack()

root.mainloop()

# %%
import tkinter as tk
from tkinter import ttk
from tkinter.messagebox import showinfo

def popup_bonus():
    win = tk.Toplevel()
    win.wm_title("Window")

    l = tk.Label(win, text="Input")
    l.grid(row=0, column=0)

    b = ttk.Button(win, text="Okay", command=win.destroy)
    b.grid(row=1, column=0)

def popup_showinfo():
    showinfo("Window", "Hello World!")

class Application(ttk.Frame):

    def __init__(self, master):
        ttk.Frame.__init__(self, master)
        self.pack()

        self.button_bonus = ttk.Button(self, text="Bonuses", command=popup_bonus)
        self.button_bonus.pack()

        self.button_showinfo = ttk.Button(self, text="Show Info", command=popup_showinfo)
        self.button_showinfo.pack()

root = tk.Tk()

app = Application(root)

root.mainloop()

# %%
import tkinter as tk

class MyDialog:

    def __init__(self, parent):
        top = self.top = tk.Toplevel(parent)
        self.myLabel = tk.Label(top, text='Enter your username below')
        self.myLabel.pack()
        self.myEntryBox = tk.Entry(top)
        self.myEntryBox.pack()
        self.mySubmitButton = tk.Button(top, text='Submit', command=self.send)
        self.mySubmitButton.pack()

    def send(self):
        self.username = self.myEntryBox.get()
        self.top.destroy()

def onClick():
    inputDialog = MyDialog(root)
    root.wait_window(inputDialog.top)
    print('Username: ', inputDialog.username)

root = tk.Tk()
mainLabel = tk.Label(root, text='Example for pop up input box')
mainLabel.pack()

mainButton = tk.Button(root, text='Click me', command=onClick)
mainButton.pack()

root.mainloop()
# Out:
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "/home/crazy/anaconda3/lib/python3.7/tkinter/__init__.py", line 1705, in __call__
#     return self.func(*args)
#   File "<ipython-input-88-2b7205012151>", line 21, in onClick
#     print('Username: ', inputDialog.username)
# AttributeError: 'MyDialog' object has no attribute 'username'

# %%
from tkinter import *
from tkinter import messagebox
win = Tk()
win.title('Survival Game')
win.geometry("500x500")
win.resizable(0,0)
win.config(bg = 'deep sky blue', cursor='pirate')


l = Label (win, fg = 'yellow', bg = 'deep sky blue',  font=('Chinyen',24),text = 'Welcome to Survival')  
l.pack_propagate(0)
l.pack(side = TOP)

def NewPage():
    print("New Page")
    win2 = Toplevel(win)
    win2.title('Survival Game')
    win2.geometry("500x500")
    win2.resizable(0,0)
    win2.config(bg = 'red', cursor='pirate')

    label1 = Label(win2, font =('Chinyen', 15),bg='grey',fg='yellow', height=2, width=30, text="New Window").grid()
    win2.mainloop()

a1=Button(win, text = ('Start Game'),font =('Chinyen', 15),bg='grey',fg='yellow', height=2, width=30, command=lambda:NewPage())
a1.pack(pady=50)

def Quit():
  answer = messagebox.askokcancel('Quit', '      Are you sure?')
  if answer:
     win.destroy()
a2=Button(win, text = ('Exit'), font =('Chinyen', 15), bg='grey',fg='yellow',height=2,width=30, command = Quit)
a2.pack()
win.mainloop()
# Out:
# New Page
# New Page
# New Page

# %%
from tkinter import *  

root = Tk()
e = Entry(root)
e.insert(END, 'default text')
e.pack()
root.mainloop()

# %%
from tkinter import *
root = Tk()

root.title('Name')

e = Entry(root)
e.pack()
e.focus_set()

b = Button(root,text='okay',command=printtext)
b.pack(side='bottom')
root.mainloop
# Out:
# adfsd

# %%
from tkinter import *
from PIL import Image, ImageTk
import tkinter as tk

class Window(Frame):

    def __init__(self,bg,master=None):
        Frame.__init__(self, master)

        self.master = master
        
        self._drag_data = {"x": 0, "y": 0, "item": None}
        self.currenty  = 400
        self.currentx = 20
        self.frame1 = tk.Frame(self.master, width=1920, height=200, background="red")
        
        
        self.ccnt = 0
        self.dcnt = 0
        self.acnt = 0
        self.icnt = 0
        self.ocnt = 0
        self.cnt =0

        image = Image.open("/home/crazy/buttons1.png")
        bg1 = ImageTk.PhotoImage(image)
        image = Image.open("/home/crazy/buttons2.png")
        bg2 = ImageTk.PhotoImage(image)
        image = Image.open("/home/crazy/buttons3.png")
        bg3 = ImageTk.PhotoImage(image)
        image = Image.open("/home/crazy/buttons4.png")
        bg4 = ImageTk.PhotoImage(image)
        image = Image.open("/home/crazy/buttons5.png")
        bg5 = ImageTk.PhotoImage(image)

        self.b1 = Button(self.frame1,text = "self.b1",bg = "red",height = 100,image = bg)
        self.b2 = Button(self.frame1,text = "self.b2",bg = "white",height = 100,image = bg)
        self.b3 = Button(self.frame1,text = "self.b3" , bg = "green",height = 100,image = bg)
        self.b4 = Button(self.frame1,text = "self.b4" , bg = "yellow",height = 100,image = bg)
        self.b5 = Button(self.frame1,text = "self.b5" , bg = "green",height = 100,image = bg)
        self.b6 = Button(self.frame1,text = "self.b6" , bg = "yellow",height = 100,image = bg)

        self.b1.bind("<ButtonPress-1>",lambda event, a = self.currentx , b =  self.currenty, c="black",d =1 , bg = bg1: self.create_token(a, b, c,d,bg))
        self.b2.bind("<ButtonPress-1>",lambda event, a = self.currentx , b =  self.currenty, c="red",d =2 ,bg = bg2: self.create_token(a, b, c,d,bg))
        self.b3.bind("<ButtonPress-1>",lambda event, a = self.currentx , b =  self.currenty, c="green",d =3 ,bg = bg3: self.create_token(a, b, c,d,bg))
        self.b4.bind("<ButtonPress-1>",lambda event,a = self.currentx , b =  self.currenty, c="white",d =4 ,bg = bg4: self.create_token(a, b, c,d,bg))
        self.b5.bind("<ButtonPress-1>",lambda event, a = self.currentx , b =  self.currenty, c="yellow",d =5 ,bg = bg5: self.create_token(a, b, c,d,bg))
        self.b6.bind("<ButtonPress-1>",self.printdict)

        # self.b1.grid(row = 0 , column = 0)
        # self.b2.grid(row = 0 , column = 1)
        # self.b3.grid(row = 0 , column = 2)
        # self.b4.grid(row = 1 , column = 0)
        # self.b5.grid(row = 1 , column = 1)
        # self.b6.grid(row = 1 , column = 2)

        self.b1.place(relwidth = 0.15,relx = 0)
        self.b2.place(relwidth = 0.15,relx = 0.17)
        self.b3.place(relwidth = 0.15,relx = 0.34)
        self.b4.place(relwidth = 0.15,relx = 0.51)
        self.b5.place(relwidth = 0.15,relx = 0.68)
        self.b6.place(relwidth = 0.15,relx = 0.85)

        self.frame7 = tk.Frame(self.master, width=1920, height = 880, background="yellow")
        self.canvas = tk.Canvas(self.frame7,width=1920, height = 880,bg = "black")


        self.canvas.tag_bind("token", "<ButtonPress-1>", self.drag_start)
        self.canvas.tag_bind("token", "<ButtonRelease-1>", self.drag_stop)
        self.canvas.tag_bind("token", "<B1-Motion>", self.drag)


        self.canvas.pack()



        self.frame1.grid(row = 1 , columnspan = 3)

        self.frame7.grid(row = 0, columnspan = 3)

        self.canvas.create_image(0, 0, image = bg, anchor = NW)

    def drag_start(self, event):
        """Begining drag of an object"""
        # record the item and its location
        self._drag_data["item"] = self.canvas.find_closest(event.x, event.y)[0]
        self._drag_data["x"] = event.x
        self._drag_data["y"] = event.y
#         print("initial",event.x,event.y)

    def drag_stop(self, event):
        """End drag of an object"""
        # reset the drag information
        self._drag_data["item"] = None
        self._drag_data["x"] = 0
        self._drag_data["y"] = 0

    def drag(self, event):
        """Handle dragging of an object"""
        # compute how much the mouse has moved
        delta_x = event.x - self._drag_data["x"]
        delta_y = event.y - self._drag_data["y"]
        # move the object the appropriate amount
        self.canvas.move(self._drag_data["item"], delta_x, delta_y)
        # record the new position
        self._drag_data["x"] = event.x
        self._drag_data["y"] = event.y
#         print("final",event.x,event.y)
        
        
    def create_token(self,x, y, color,label,bg):
        
        print("button ",label," is pressed")
#         print(self.currentx)
        self.cnt +=1
        x = self.currentx
        y = self.currenty   
        
        if label==2:
#             name = "conv"+str(self.ccnt)
            self.ccnt +=1
            self.currentx +=120
        elif label==3:
#             name = "dense"+str(self.dcnt)
            self.currentx +=60
            self.dcnt +=1
        elif label ==4:
#             name = "activation"+str(self.acnt)
            self.currentx +=120
            self.acnt +=1
        elif label ==1:
            if self.icnt>=1:
                y = self.currenty -120*self.icnt
                x = 20
                self.icnt +=1
#             name = "input"+str(self.icnt)
            else:
                self.currentx +=120
                self.icnt +=1
        elif label ==5:
            y = self.currenty -120*self.ocnt
            x = 1800
            self.ocnt +=1
#             name =="output"+str(self.ocnt)
        token = self.canvas.create_image(x,y,image = bg,anchor=NW,tags =("token",))
        
        self.canvas.tag_bind(token ,'<Double-Button-1>', self.itemClicked)#         self._drag_data[self.cnt]["item"] = token
#         self._drag_data[self.cnt]["x"] = x
#         self._drag_data[self.cnt]["y"] = y
#         print(str(token))
        
        
    def itemClicked(self,event):
        canvas_item_id = event.widget.find_withtag('current')[0]
        print('Item', canvas_item_id, 'Clicked!')
        
    def printdict(self,event):
        print(self._drag_data)
        
    def regionOfInterest(self):
        root.config(cursor="plus")
        canvas.bind("<Button-1>", self.imgClick)


    def client_exit(self):
        exit()

    def imgClick(self, event):
        print(self.counter)

        if self.counter < 3:
            x = canvas.canvasx(event.x)
            y = canvas.canvasy(event.y)
            self.pos.append((x, y))
            print(self.pos)
            canvas.create_line(x - 5, y, x + 5, y, fill="red", tags="crosshair")
            canvas.create_line(x, y - 5, x, y + 5, fill="red", tags="crosshair")
            self.counter += 1
        else:
            canvas.unbind("<Button 1>")
            root.config(cursor="arrow")
            self.counter = 0


root = Tk()
root.geometry("1880x1080")
root.resizable(width = "True",height = "True")
image = Image.open("bg3.png")
bg = ImageTk.PhotoImage(image)
app = Window(bg=bg,master = root)
root.mainloop()
# Out:
# button  1  is pressed
# button  1  is pressed
# button  2  is pressed
# button  3  is pressed
# Item 4 Clicked!
# Item 4 Clicked!
# Item 5 Clicked!

# %%
from tkinter import *
from PIL import Image, ImageTk

class Window(Frame):

    def __init__(self, master=None):
        Frame.__init__(self, master)

        self.master = master
        self.pos = []
        self.master.title("GUI")
        self.pack(fill=BOTH, expand=1)

        self.counter = 0

        menu = Menu(self.master)
        self.master.config(menu=menu)

        file = Menu(menu)
        file.add_command(label="Exit", command=self.client_exit)
        menu.add_cascade(label="File", menu=file)
        analyze = Menu(menu)

        analyze.add_command(label="Region of Interest", 
        command=self.regionOfInterest)

        menu.add_cascade(label="Analyze", menu=analyze)
        load = Image.open("bg3.png")
        render = ImageTk.PhotoImage(load)

        img = Label(self, image=render)
        img.image = render
        img.place(x=0, y=0)

    def regionOfInterest(self):
        root.config(cursor="plus")
        canvas.bind("<Button-1>", self.imgClick)


    def client_exit(self):
        exit()

    def imgClick(self, event):
        print(self.counter)

        if self.counter < 3:
            x = canvas.canvasx(event.x)
            y = canvas.canvasy(event.y)
            self.pos.append((x, y))
            print(self.pos)
            canvas.create_line(x - 5, y, x + 5, y, fill="red", tags="crosshair")
            canvas.create_line(x, y - 5, x, y + 5, fill="red", tags="crosshair")
            self.counter += 1
        else:
            canvas.unbind("<Button 1>")
            root.config(cursor="arrow")
            self.counter = 0


root = Tk()
imgSize = Image.open("bg3.png")
tkimage =  ImageTk.PhotoImage(imgSize)
w, h = imgSize.size

canvas = Canvas(root, width=w, height=h)
canvas.create_image((w/2,h/2),image=tkimage)
canvas.pack()

root.geometry("%dx%d"%(w,h))
app = Window(root)
root.mainloop()
# Out:
# 0
# [(273.0, 109.0)]
# 1
# [(273.0, 109.0), (599.0, 114.0)]
# 2
# [(273.0, 109.0), (599.0, 114.0), (602.0, 307.0)]
# 3

# %%
app._drag_data
# Out:
# {'x': 0, 'y': 0, 'item': None}

# %%
from collections import defaultdict 
class Graph: 
    def __init__(self,vertices): 
        self.V= vertices  
        self.graph = defaultdict(list)  
        
    def addEdge(self,u,v): 
        self.graph[u].append(v) 

    def printAllPathsUtil(self, u, d, visited, path): 

        visited[u]= True
        path.append(u)  
        if u ==d: 
            print(path)
        else: 
            for i in self.graph[u]: 
                if visited[i]==False: 
                    self.printAllPathsUtil(i, d, visited, path) 
        path.pop() 
        visited[u]= False
    def printAllPaths(self,s, d): 
        visited =[False]*(self.V) 
        path = [] 
        self.printAllPathsUtil(s, d,visited, path)

# %%
g = Graph(4)

# %%
g.addEdge(0, 1)

# %%
g.addEdge(1, 2)

# %%
g = Graph(5) 
g.addEdge(0, 1) 
g.addEdge(1, 2) 
g.addEdge(2, 3) 
g.addEdge(3, 4) 
# g.addEdge(2, 1) 
# g.addEdge(1, 3) 
   
s = 0 ; d = 4
print ("Following are all different paths from %d to %d :" %(s, d)) 
g.printAllPaths(s, d)
# Out:
# Following are all different paths from 0 to 4 :
# [0, 1, 2, 3, 4]

# %%
from tkinter import *

root = Tk()
canvas = Canvas(root)
canvas.pack()

def itemClicked(event):
    canvas_item_id = event.widget.find_withtag('current')[0]
    print('Item', canvas_item_id, 'Clicked!')

def add_canvas_item(x,y):
    canvas_item_id = canvas.create_oval(x-50,y-50,x+50,y+50, fill='green')
    canvas.tag_bind(canvas_item_id ,'<ButtonPress-1>', itemClicked)

add_canvas_item(100,100)    # Test item 1
add_canvas_item(250,150)    # Test item 2

root.mainloop()
# Out:
# Item 2 Clicked!
# Item 2 Clicked!
# Item 1 Clicked!
# Item 1 Clicked!
# Item 1 Clicked!
# Item 2 Clicked!
# Item 1 Clicked!
# Item 2 Clicked!
# Item 1 Clicked!
