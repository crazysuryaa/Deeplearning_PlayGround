# %%
import tkinter as tk

# %%
from tkinter import *

# %%
       
from tkinter import font  as tkfont

# %%
class Frame1:
    def __init__(self,parent):
        frame1  = Frame(parent,bg = "red")
        label = tk.Label(frame1, text="This is the start page", font=parent.title_font)
        label.pack(side="top", fill="x", pady=10)

        button1 = tk.Button(frame1, text="Go to Page One",
                            command=lambda: parent.show_frame("frame0"))
        button2 = tk.Button(frame1, text="Go to Page Two",
                            command=lambda: parent.show_frame("frame1"))
        button1.pack()
        button2.pack()
        
class Frame2:
    def __init__(self,parent):
        frame2 = Frame(parent, bg = "red")
        label = tk.Label(frame2, text="This is the end page", font=parent.title_font)
        label.pack(side="top", fill="x", pady=10)

        button1 = tk.Button(frame2, text="Go to Page One",
                            command=lambda: parent.show_frame("frame0"))
        button2 = tk.Button(frame2, text="Go to Page Two",
                            command=lambda: parent.show_frame("frame1"))
        button1.pack()
        button2.pack()

# %%
root = Tk()
root.geometry("1000x1000")
root.title_font = tkfont.Font(family='Helvetica', size=18, weight="bold", slant="italic")
container = Frame(root ,bg = "yellow")
container.pack(side="top", fill="both", expand=True)
container.grid_rowconfigure(0, weight=1)
container.grid_columnconfigure(0, weight=1)
controller = root


def show_frame(page_name):
    frame = frames[page_name]
    frame.tkraise()
    
    
# frame1 = Frame(container,bg = "blue")
# label = tk.Label(frame1, text="This is the start page", font=controller.title_font)
# label.pack(side="top", fill="x", pady=10)

# button1 = tk.Button(frame1, text="Go to Page One",
#                     command=lambda: show_frame("frame0"))
# button2 = tk.Button(frame1, text="Go to Page Two",
#                     command=lambda: show_frame("frame1"))
# button1.pack()
# button2.pack()


# frame2 = Frame(container, bg = "red")
# label = tk.Label(frame2, text="This is the end page", font=controller.title_font)
# label.pack(side="top", fill="x", pady=10)

# button1 = tk.Button(frame2, text="Go to Page One",
#                     command=lambda: show_frame("frame0"))
# button2 = tk.Button(frame2, text="Go to Page Two",
#                     command=lambda: show_frame("frame1"))
# button1.pack()
# button2.pack()


frames = {}
for ind,frame in enumerate([Frame1,Frame2]):
    frame = Frame1(root)
    frames["frame"+str(ind)] = frame
    frame.grid(row=0, column=0, sticky="nsew")


    
show_frame("frame0")






root.mainloop()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-34-50426aa0186d> in <module>
#      42     frame = Frame1(root)
#      43     frames["frame"+str(ind)] = frame
# ---> 44     frame.grid(row=0, column=0, sticky="nsew")
#      45
#      46
#
# AttributeError: 'Frame1' object has no attribute 'grid'

# %%
import tkinter as tk                # python 3
from tkinter import font  as tkfont # python 3
#import Tkinter as tk     # python 2
#import tkFont as tkfont  # python 2

class SampleApp(tk.Tk):

    def __init__(self, *args, **kwargs):
        tk.Tk.__init__(self, *args, **kwargs)

        self.title_font = tkfont.Font(family='Helvetica', size=18, weight="bold", slant="italic")

        # the container is where we'll stack a bunch of frames
        # on top of each other, then the one we want visible
        # will be raised above the others
        container = tk.Frame(self)
        container.pack(side="top", fill="both", expand=True)
        container.grid_rowconfigure(0, weight=1)
        container.grid_columnconfigure(0, weight=1)

        self.frames = {}
        for F in (StartPage, PageOne, PageTwo):
            page_name = F.__name__
            frame = F(parent=container, controller=self)
            self.frames[page_name] = frame

            # put all of the pages in the same location;
            # the one on the top of the stacking order
            # will be the one that is visible.
            frame.grid(row=0, column=0, sticky="nsew")

        self.show_frame("StartPage")

    def show_frame(self, page_name):
        '''Show a frame for the given page name'''
        frame = self.frames[page_name]
        frame.tkraise()


class StartPage(tk.Frame):

    def __init__(self, parent, controller):
        tk.Frame.__init__(self, parent)
        self.controller = controller
        label = tk.Label(self, text="This is the start page", font=controller.title_font)
        label.pack(side="top", fill="x", pady=10)

        button1 = tk.Button(self, text="Go to Page One",
                            command=lambda: controller.show_frame("PageOne"))
        button2 = tk.Button(self, text="Go to Page Two",
                            command=lambda: controller.show_frame("PageTwo"))
        button1.pack()
        button2.pack()


class PageOne(tk.Frame):

    def __init__(self, parent, controller):
        tk.Frame.__init__(self, parent)
        self.controller = controller
        label = tk.Label(self, text="This is page 1", font=controller.title_font)
        label.pack(side="top", fill="x", pady=10)
        button = tk.Button(self, text="Go to the start page",
                           command=lambda: controller.show_frame("StartPage"))
        button.pack()


class PageTwo(tk.Frame):

    def __init__(self, parent, controller):
        tk.Frame.__init__(self, parent)
        self.controller = controller
        label = tk.Label(self, text="This is page 2", font=controller.title_font)
        label.pack(side="top", fill="x", pady=10)
        button = tk.Button(self, text="Go to the start page",
                           command=lambda: controller.show_frame("StartPage"))
        button.pack()


if __name__ == "__main__":
    app = SampleApp()
    app.mainloop()

# %%
import sys

sys.path.insert(1, '/home/crazy/UI/labelImgmaster')

# %%
from labelImg import main

# %%
main()
# Out:
# 0

# %%
from tkinter import filedialog
from tkinter import *

root = Tk()
root.filename =  filedialog.asksaveasfilename(initialdir = "/",title = "Select file",filetypes = (("jpeg files","*.jpg"),("all files","*.*")))
print (root.filename)
# Out:
# ()

# %%
from  tkinter import filedialog
import tkinter as tk
from tkinter import *
root = Tk()
root.directory = filedialog.askdirectory()
print (root.directory)

root.mainloop()
# Out:
# /mnt/DATA/UI

# %%
import sys
sys.path.insert(1, '/home/crazy/UI/labelImgmaster')


from labelImg import main
from reshapeimages import reshape



from tkinter import *
import tkinter as tk                # python 3
from tkinter import font  as tkfont # python 3
from  tkinter import filedialog
class StartPage(tk.Frame):

    def __init__(self, parent, controller):
        tk.Frame.__init__(self, parent)
        self.controller = controller
        bglabel = Label(self,image = controller.bg)
        bglabel.place(relwidth  = 1 , relheight = 1)

        button1 = tk.Button(self, text="Defect Detection",
                            command=lambda: controller.show_frame("Defect"))
        button2 = tk.Button(self, text="Colour training",
                            command=lambda: controller.show_frame("Color"))
        button1.place(relx = 0.4,rely = 0.5)
        button2.place(relx = 0.4,rely = 0.6)


class Defect(tk.Frame):

    def __init__(self, parent, controller):
        tk.Frame.__init__(self, parent)
        self.controller = controller
#         label = tk.Label(self, text="This is page 1", font=controller.title_font)
        bglabel = Label(self,image = controller.bg)
        bglabel.place(relwidth  = 1 , relheight = 1)
#         label.pack(side="top", fill="x", pady=10)
        button1 = tk.Button(self, text="Create New model",
                           command=lambda: controller.show_frame("Newmodel"))
        button2 = tk.Button(self, text="Update exisiting model",
                           command=lambda: controller.show_frame("Existing"))
        
        button3 = tk.Button(self, text="start page",
                           command=lambda: controller.show_frame("StartPage"))
                            
        button1.place(relx = 0.4,rely = 0.5)
        button2.place(relx = 0.4,rely = 0.6)
        button3.place(relx = 0,rely = 0)


class Newmodel(tk.Frame):

    def __init__(self, parent, controller):
        tk.Frame.__init__(self, parent)
        self.controller = controller
#         label = tk.Label(self, text="This is page 1", font=controller.title_font)
        bglabel = Label(self,image = controller.bg)
        bglabel.place(relwidth  = 1 , relheight = 1)
#         label.pack(side="top", fill="x", pady=10)
        
        self.userlabel = Label(self,text = "Make sure all images area of same size")
                            
        self.button1 = tk.Button(self, text="Resize Images",
                                   command= self.resize)
                            
        button2 = tk.Button(self, text="createLabels",
                                   command= self.createlabels)
                            
        button3 = tk.Button(self, text="Train",
                               command= self.createlabels)
        
        button4 = tk.Button(self, text="start page",
                           command=lambda: controller.show_frame("StartPage"))
                            
        self.button1.place(relx = 0.4,rely = 0.5)
        button2.place(relx = 0.4,rely = 0.6)
        button3.place(relx = 0.4,rely = 0.7)
                            
        button4.place(relx = 0,rely = 0)
        self.userlabel.place(relx = 0.4,rely = 0.4)
        
    def resize(self):
        print("resizing")
        self.button1.destroy()
        self.button5 = tk.Button(self, text="224",command=lambda: self.selectedsize("224"))
        self.button6 = tk.Button(self, text="192",command=lambda: self.selectedsize("192"))
        self.button7 = tk.Button(self, text="416",command=lambda: self.selectedsize("416"))
        
        self.button5.place(relx = 0.3,rely = 0.5)
        self.button6.place(relx = 0.4,rely = 0.5)
        self.button7.place(relx = 0.5,rely = 0.5)
        

        
    def selectedsize(self,size):
        
        directory = filedialog.askdirectory()
        print(directory,size)
        reshape(directory,int(size))
        self.button5.destroy()
        self.button6.destroy()
        self.button7.destroy()
        

    def createlabels(self):
        print("newmodel")
            
                            
                            
class Existing(tk.Frame):

    def __init__(self, parent, controller):
        tk.Frame.__init__(self, parent)
        self.controller = controller
#         label = tk.Label(self, text="This is page 1", font=controller.title_font)
        bglabel = Label(self,image = controller.bg)
        bglabel.place(relwidth  = 1 , relheight = 1)
#         label.pack(side="top", fill="x", pady=10)
        button1 = tk.Button(self, text="Create New model",
                           command=lambda: controller.show_frame("Newmodel"))
        button2 = tk.Button(self, text="Update existing model",
                           command=lambda: controller.show_frame("Existing"))
        
        button3 = tk.Button(self, text = "start page",
                           command=lambda: controller.show_frame("StartPage"))
                            
        button1.place(relx = 0.4,rely = 0.5)
        button2.place(relx = 0.4,rely = 0.6)
        button3.place(relx = 0,rely = 0)
                            
class Color(tk.Frame):

    def __init__(self, parent, controller):
        tk.Frame.__init__(self, parent)
        self.controller = controller
        bglabel = Label(self,image = controller.bg)
        bglabel.place(relwidth  = 1 , relheight = 1)
        button = tk.Button(self, text = "start page",
                           command=lambda: controller.show_frame("StartPage"))
        
        button.place(relx = 0.4,rely = 0.5)
#         button2.place(relx = 0.4,rely = 0.6)

class SampleApp():

    def __init__(self,root,bg):

        self.title_font = tkfont.Font(family='Helvetica', size=18, weight="bold", slant="italic")
        self.bg = bg

        container = tk.Frame(root )
        label = Label(container,image = self.bg)
        label.place(relwidth  = 1 , relheight = 1)
        container.pack(side="top", fill="both", expand=True)
        container.grid_rowconfigure(0, weight=1)
        container.grid_columnconfigure(0, weight=1)

        self.frames = {}
        for F in (StartPage,Defect,Newmodel,Existing,Color):
            page_name = F.__name__
            frame = F(parent=container, controller=self)
            self.frames[page_name] = frame
            frame.grid(row=0, column=0, sticky="nsew")
        self.show_frame("StartPage")

    def show_frame(self, page_name):
        '''Show a frame for the given page name'''
        frame = self.frames[page_name]
        frame.tkraise()

# %%
from PIL import Image, ImageTk

# %%
root = Tk()
image = Image.open("zentron.png")
bg = ImageTk.PhotoImage(image)
root.geometry("600x600")
SampleApp(root,bg)
root.mainloop()
# Out:
# resizing
# /home/crazy/Desktop/Zentron/defect detection/defect detection/dataset/akshay work binary/backgroung removed 224
# Directory  created successfully
# /home/crazy/Desktop/Zentron/defect detection/defect detection/dataset/akshay work binary/backgroung removed/1.png
# /home/crazy/Desktop/Zentron/defect detection/defect detection/dataset/akshay work binary/backgroung removed/reshapeddataset224/1.png
# /home/crazy/Desktop/Zentron/defect detection/defect detection/dataset/akshay work binary/backgroung removed/10900.png
# /home/crazy/Desktop/Zentron/defect detection/defect detection/dataset/akshay work binary/backgroung removed/reshapeddataset224/10900.png
# /home/crazy/Desktop/Zentron/defect detection/defect detection/dataset/akshay work binary/backgroung removed/15200.png
# /home/crazy/Desktop/Zentron/defect detection/defect detection/dataset/akshay work binary/backgroung removed/reshapeddataset224/15200.png
# ...

# %%
import cv2

# %%
img = cv2.imread("/home/crazy/Downloads/zentron.png")

# %%
img  =cv2.resize(img , (600,600))

# %%
cv2.imwrite("/home/crazy/UI/zentron.png",img)
# Out:
# True
